# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
churn=pd.read_csv('/content/Churn_Modelling.csv')

# %%
churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churn.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
churn.shape
# Out:
# (10000, 14)

# %%
churn.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
cont= churn[churn.Exited == 0]
leave = churn[churn.Exited == 1]

# %%
print(cont.shape)
print(leave.shape)
# Out:
# (7963, 14)
# (2037, 14)

# %%
cont.EstimatedSalary.describe()
# Out:
# count      7963.000000
# mean      99738.391772
# std       57405.586966
# min          90.070000
# 25%       50783.490000
# 50%       99645.040000
# 75%      148609.955000
# max      199992.480000
# Name: EstimatedSalary, dtype: float64

# %%
leave.EstimatedSalary.describe()
# Out:
# count      2037.000000
# mean     101465.677531
# std       57912.418071
# min          11.580000
# 25%       51907.720000
# 50%      102460.840000
# 75%      152422.910000
# max      199808.100000
# Name: EstimatedSalary, dtype: float64

# %%
churn.groupby('Exited').mean()
# Out:
# <ipython-input-14-65b76d046350>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   churn.groupby('Exited').mean()
#           RowNumber    CustomerId  CreditScore        Age    Tenure  \
# Exited
# 0       5024.694964  1.569117e+07   651.853196  37.408389  5.033279
# 1       4905.917526  1.569005e+07   645.351497  44.837997  4.932744
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# Exited
# 0       72745.296779       1.544267   0.707146        0.554565
# 1       91108.539337       1.475209   0.699067        0.360825
#
#         EstimatedSalary
# Exited
# 0          99738.391772
# 1         101465.677531

# %%
churn.value_counts()
# Out:
# RowNumber  CustomerId  Surname     CreditScore  Geography  Gender  Age  Tenure  Balance    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 1          15634602    Hargrave    619          France     Female  42   2       0.00       1              1          1               101348.88        1         1
# 6671       15667932    Bellucci    758          Spain      Female  43   10      0.00       2              1          1               55313.44         0         1
# 6664       15766185    She         850          Germany    Male    31   4       146587.30  1              1          1               89874.82         0         1
# 6665       15667632    Birdseye    703          France     Female  42   7       0.00       2              0          1               72500.68         0         1
# 6666       15599024    Hope        506          Spain      Male    32   8       0.00       2              0          1               182692.80        0         1
# ...

# %%
cont_sample = cont.sample(n=7963)

# %%
new = pd.concat([cont_sample, leave], axis=0)

# %%
new.head()
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 8699       8700    15684469    Hsiung          841   Germany    Male   32
# 4710       4711    15685653    Benson          585   Germany  Female   40
# 8656       8657    15791342  Johnston          660     Spain    Male   31
# 2252       2253    15604782       Tan          733   Germany  Female   33
# 8143       8144    15609058       Wan          676    France    Male   23
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 8699       2  117070.21              1          1               0
# 4710       3  162261.01              2          1               0
# 8656       1   84560.04              1          1               1
# 2252       7  187257.94              1          0               1
# 8143       1  107787.47              1          0               1
#
#       EstimatedSalary  Exited
# 8699        113482.20       0
# 4710        137028.51       0
# ...

# %%
new.tail()
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9981       9982    15672754     Burbidge          498   Germany    Male   42
# 9982       9983    15768163      Griffin          655   Germany  Female   46
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9981       3  152039.70              1          1               1
# 9982       7  137145.12              1          1               0
# 9991       4   88381.21              1          1               0
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
#
#       EstimatedSalary  Exited
# 9981         53445.17       1
# 9982        115146.40       1
# ...

# %%
new['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
new.groupby('Exited').mean()
# Out:
# <ipython-input-22-525f64806e0f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new.groupby('Exited').mean()
#           RowNumber    CustomerId  CreditScore        Age    Tenure  \
# Exited
# 0       5024.694964  1.569117e+07   651.853196  37.408389  5.033279
# 1       4905.917526  1.569005e+07   645.351497  44.837997  4.932744
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# Exited
# 0       72745.296779       1.544267   0.707146        0.554565
# 1       91108.539337       1.475209   0.699067        0.360825
#
#         EstimatedSalary
# Exited
# 0          99738.391772
# 1         101465.677531

# %%
x = new.drop(columns=['Surname','RowNumber','NumOfProducts','Geography','Gender','Tenure','Exited'], axis=1)
y = new['Exited']

# %%
print(x)
# Out:
#       CustomerId  CreditScore  Age    Balance  HasCrCard  IsActiveMember  \
# 8699    15684469          841   32  117070.21          1               0
# 4710    15685653          585   40  162261.01          1               0
# 8656    15791342          660   31   84560.04          1               1
# 2252    15604782          733   33  187257.94          0               1
# 8143    15609058          676   23  107787.47          0               1
# ...          ...          ...  ...        ...        ...             ...
# 9981    15672754          498   42  152039.70          1               1
# 9982    15768163          655   46  137145.12          1               0
# 9991    15769959          597   53   88381.21          1               0
# 9997    15584532          709   36       0.00          0               1
# 9998    15682355          772   42   75075.31          1               0
#
#       EstimatedSalary
# 8699        113482.20
# 4710        137028.51
# ...

# %%
print(y)
# Out:
# 8699    0
# 4710    0
# 8656    0
# 2252    0
# 8143    0
#        ..
# 9981    1
# 9982    1
# 9991    1
# 9997    1
# 9998    1
# Name: Exited, Length: 10000, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (10000, 7) (8000, 7) (2000, 7)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('accuracy on training data: ',training_data_accuracy)
# Out:
# accuracy on training data:  0.79625

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
print('accuracy on test data: ',test_data_accuracy)
# Out:
# accuracy on test data:  0.7965
